# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([2,4,5,7,8])
y = np.array([8,13,17,24,26])
plt.figure()
plt.scatter(x,y,color="red")
h = 3*x+3
print(h)
plt.figure()
plt.plot(x,h,c="b",marker="o")
plt.scatter(x,y,c="r")

x.size
def cost(y,pred):
  return ((pred-y)**2).sum(axis=0) / (2*y.shape[0])

def predict(w, x):
    return w[0]+w[1]*x
# Out:
# [ 9 15 18 24 27]

# %%
# inisialisasi
w = [0.1, 0.03]
# ubah w
# eval cost
